# %% [markdown]
# <b><h1>Introdução a visão computacional 🤖<h1/><b/>

# %% [markdown]
# <h3>O que é?</h3>

# %% [markdown]
# Visão computacional é o campo de IA que faz uso do <a href="https://www.ibm.com/think/topics/machine-learning">machine learning</a> e <a href="https://www.ibm.com/think/topics/neural-networks">redes neurais</a>, para ensinar computadores e sistemas afim de extrair informações de imagens, videos e outras formas visuais, podendo prestar auxílio com recomendações ou tomando decisões quando reconhecem algum defeito ou problema.É como se o a IA fizesse o computador pensar, já a visão computacional fizesse enxergar, observar e entender.

# %% [markdown]
# <img src="data:image/jpeg;base64,..."><img>

# %% [markdown]
# <h3>Como funciona?<h3/>

# %% [markdown]
# Visão computacional funciona similar ao nossos olhos e cerébro, para extrair qualquer informação nossos olhos capturam a imagem, depois mandam sinais para o cerébro. Depois o cerébro pega esses sinais, converte e interpreta em informações sobre o objeto que ele reconheceu. Já na visão computacional o processo é muito similar, sendo os olhos algum dispositivo que leia imagem como câmeras ou webcams, os cérebro sendo a máquina que faz uso IA pra processear as imagens geradas pelass câmeras gerando informações.

# %% [markdown]
# <img src="https://miro.medium.com/max/1200/0*m3k9-6qgUK9LyKWS.png"><img/>

# %% [markdown]
# <h3>Exemplo Prático<h3/>

# %%
# !wget -O teste_opencv https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAUPdTmCVVo8uzR-CzzIl9JV1YYvFPwraRuQ&s

# %% [markdown]
# Nesse exemplo utilizaremos a seguintes bibliotecas, o opencv, que é uma biblioteca voltada pra dessenvolvimento de visão computacional, midiapipe que é uma biblioteca de machine learning para extração de informações de imagens, videos, entre outras fontes visuais, por fim o cv2_imshow do próprio que google colab, que é uma alternativa para renderização de imagens dentro da plataforma.

# %%
import cv2
import  mediapipe as mp
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/teste_opencv") # Load the image directly

# %%
# Check if the image was loaded successfully
if img is None:
    print("Error: Could not load image. Please check the file path and ensure the image exists.")
else:
    mpHands = mp.solutions.hands
    hands = mpHands.Hands()
    mpDraw = mp.solutions.drawing_utils

    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS)

# %%
cv2_imshow(img) # Display the processed image

# %% [markdown]
# Imagem original:

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAUPdTmCVVo8uzR-CzzIl9JV1YYvFPwraRuQ&s">

# %% [markdown]
# Imagem com handtracking:

# %% [markdown]
# <img src="data:image/png;base64,..."><img/>
